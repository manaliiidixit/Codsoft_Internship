# %% [markdown]
# <a href="https://colab.research.google.com/github/manaliiidixit/Codsoft_Internship/blob/main/Codsoft_creditcard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn import svm

# %%
data = pd.read_csv('/content/creditcard.csv')
# Out:
# <ipython-input-2-1e88a68a45d2>:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.tail()
# Out:
#         Time        V1         V2        V3        V4        V5        V6  \
# 33755  37372  0.597155  -1.457940  0.648770 -1.154721 -1.384692 -0.114190
# 33756  37373 -7.504323 -15.633772 -4.215051  1.507090 -5.412604  3.243205
# 33757  37373  1.242547   0.010297 -1.206012  0.083576  2.171891  3.391877
# 33758  37373 -1.065865   1.177477  2.083773  1.296198  0.564073  0.295974
# 33759  37373 -0.302250   0.828254 -0.311542 -1.108255  2.533421  3.274040
#
#              V7        V8        V9  ...       V21                  V22  \
# 33755 -0.353940  0.077492  1.434997  ...  0.266727    0.391858868587825
# 33756  4.422388 -0.423582  0.392031  ...  2.323590    -2.53917289990935
# 33757 -0.417041  0.793206 -0.149793  ...  0.031822  -0.0638428726104072
# 33758  0.656915  0.158767 -1.006866  ... -0.157601   -0.518893364163089
# 33759  0.134693  0.933364 -0.505897  ... -0.314500                    -
#
#             V23       V24       V25       V26       V27       V28   Amount  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33760 entries, 0 to 33759
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    33760 non-null  int64
#  1   V1      33760 non-null  float64
#  2   V2      33760 non-null  float64
#  3   V3      33760 non-null  float64
#  4   V4      33760 non-null  float64
#  5   V5      33760 non-null  float64
#  6   V6      33760 non-null  float64
#  7   V7      33760 non-null  float64
#  8   V8      33760 non-null  float64
#  9   V9      33760 non-null  float64
#  10  V10     33760 non-null  float64
#  11  V11     33760 non-null  float64
#  12  V12     33760 non-null  float64
#  13  V13     33760 non-null  float64
#  14  V14     33760 non-null  float64
#  15  V15     33760 non-null  float64
#  16  V16     33760 non-null  float64
#  17  V17     33760 non-null  float64
#  18  V18     33760 non-null  float64
#  19  V19     33760 non-null  float64
# ...

# %%
data.shape
# Out:
# (33760, 31)

# %%
data.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  33760.000000  33760.000000  33760.000000  33760.000000  33760.000000
# mean   23186.502044     -0.210769      0.090212      0.718086      0.205183
# std    12310.554703      1.849230      1.545474      1.565917      1.413512
# min        0.000000    -30.552380    -40.978852    -31.103685     -5.172595
# 25%    11323.250000     -0.957639     -0.480557      0.248743     -0.705571
# 50%    28260.500000     -0.240862      0.125560      0.834797      0.194608
# 75%    33557.250000      1.162820      0.767388      1.460421      1.089341
# max    37373.000000      1.960497     16.713389      4.101716     13.143668
#
#                  V5            V6            V7            V8            V9  \
# count  33760.000000  33760.000000  33760.000000  33760.000000  33760.000000
# mean      -0.215343      0.092961     -0.118041      0.031774      0.285485
# ...

# %%
len(data)
# Out:
# 33760

# %%
data['Class'].value_counts()
# Out:
# 0.0    33656
# 1.0      103
# Name: Class, dtype: int64

# %%
good = data[data.Class == 0]
fraud = data[data.Class == 1]

# %%
fraud
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541      406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623      472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920    4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108    6986 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329    7519  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...      ...       ...       ...       ...       ...       ...       ...
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
#
#              V7        V8        V9  ...       V21                V22  \
# ...

# %%
good.shape
# Out:
# (33656, 31)

# %%
good.Amount.describe()
# Out:
# count    33656.000000
# mean        83.011607
# std        227.811004
# min          0.000000
# 25%          6.990000
# 50%         21.040000
# 75%         75.000000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     103.000000
# mean       90.471165
# std       247.173335
# min         0.000000
# 25%         1.000000
# 50%         3.760000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
good_sample = good.sample(n=25)

# %%
new_data = pd.concat([good_sample,fraud],axis=0)

# %%
new_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
#
#              V7        V8        V9  ...       V21                V22  \
# 30442 -6.805053  2.928356 -4.917130  ...  1.691042           0.920021
# 30473 -7.281328  3.332250 -3.679659  ...  1.550473           0.614573
# 30496 -6.311699  3.449167 -5.416284  ...  1.194888          -0.845753
# 31002 -6.958679  3.877795 -5.541529  ...  1.128641           -0.96296
# 33276 -5.283435  0.131619  0.658176  ... -0.734308  -0.59992625988411
#
#             V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
x1 = new_data.drop('Class',axis = 1)

# %%
y1 = new_data['Class']

# %%
y1
# Out:
# 18811    0.0
# 27050    0.0
# 11863    0.0
# 20762    0.0
# 13114    0.0
#         ...
# 30442    1.0
# 30473    1.0
# 30496    1.0
# 31002    1.0
# 33276    1.0
# Name: Class, Length: 128, dtype: float64

# %%
x1
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 18811  29786 -0.527159  0.608478  1.244170  1.175936  0.063832  0.572137
# 27050  34365 -0.594643  0.213801  1.478996  0.514697  1.575588  5.042489
# 11863  20391  1.254478 -0.257222  0.896744 -0.600173 -0.942879 -0.561004
# 20762  31254  1.089024 -0.384705  1.074202  0.337911 -1.131061 -0.460866
# 13114  23022  1.002716  0.011594  0.772345  0.840059 -0.564718 -0.626773
# ...      ...       ...       ...       ...       ...       ...       ...
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
#
#              V7        V8        V9  ...       V20       V21  \
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size=0.2)

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.fit(x_test,y_test)
# Out:
# LogisticRegression()

# %%
x1_prediction = model.predict(x_train)

# %%
x1_accuracy = accuracy_score(x1_prediction,y_train)

# %%
x1_accuracy
# Out:
# 0.8529411764705882

# %%
y1_predict = model.predict(x_test)

# %%
y1_accuracy = accuracy_score(y1_predict,y_test)

# %%
y1_accuracy
# Out:
# 1.0
